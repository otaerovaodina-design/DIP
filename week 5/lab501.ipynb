# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('bright1.jpeg', cv2.IMREAD_GRAYSCALE)
equalized_image = cv2.equalizeHist(image)

plt.figure(figsize=(10,5))

plt.subplot(2, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(2, 2, 2)
plt.hist(image.ravel(), 256, [0,256])
plt.title('Histogram (Original)')

plt.subplot(2, 2, 3)
plt.imshow(equalized_image, cmap='gray')
plt.title('Equalized Image')
plt.axis('off')

plt.subplot(2, 2, 4)
plt.hist(equalized_image.ravel(), 256, [0,256])
plt.title('Histogram (Equalized)')

plt.show()
# Out:
# /tmp/ipython-input-3484856185.py:15: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(image.ravel(), 256, [0,256])
# /tmp/ipython-input-3484856185.py:24: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(equalized_image.ravel(), 256, [0,256])

# %%
import cv2
import matplotlib.pyplot as plt

color_image = cv2.imread('flower.jpg')

(b, g, r) = cv2.split(color_image)

equalized_b = cv2.equalizeHist(b)
equalized_g = cv2.equalizeHist(g)
equalized_r = cv2.equalizeHist(r)

equalized_color_image = cv2.merge([equalized_b, equalized_g, equalized_r])

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(color_image, cv2.COLOR_BGR2RGB))
plt.title('Original Color Image')
plt.axis('on')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(equalized_color_image, cv2.COLOR_BGR2RGB))
plt.title('Equalized Color Image (Channels Separately)')
plt.axis('on')

plt.show()

# %%
import cv2
import numpy as np
from skimage import exposure
import matplotlib.pyplot as plt

image_source = cv2.imread('designer.jpg', cv2.IMREAD_GRAYSCALE)
image_target = cv2.imread('computer.png', cv2.IMREAD_GRAYSCALE)

matched_image = exposure.match_histograms(image_source, image_target)

plt.figure(figsize=(15,5))

plt.subplot(3, 3, 1)
plt.imshow(image_source, cmap='gray')
plt.title('Source Image')
plt.axis('off')

plt.subplot(3, 3, 2)
plt.hist(image_source.ravel(), 256, [0,256])
plt.title('Histogram (Source)')

plt.subplot(3, 3, 4)
plt.imshow(image_target, cmap='gray')
plt.title('Target Image')
plt.axis('off')

plt.subplot(3, 3, 5)
plt.hist(image_target.ravel(), 256, [0,256])
plt.title('Histogram (Target)')

plt.subplot(3, 3, 7)
plt.imshow(matched_image, cmap='gray')
plt.title('Matched Image')
plt.axis('off')

plt.subplot(3, 3, 8)
plt.hist(np.array(matched_image).ravel(), 256, [0,256])
plt.title('Histogram (Matched)')

plt.show()
# Out:
# /tmp/ipython-input-1842210650.py:19: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(image_source.ravel(), 256, [0,256])
# /tmp/ipython-input-1842210650.py:28: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(image_target.ravel(), 256, [0,256])
# /tmp/ipython-input-1842210650.py:37: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(np.array(matched_image).ravel(), 256, [0,256])

# %%
import cv2
import numpy as np
from skimage import exposure
import matplotlib.pyplot as plt

image_source = cv2.imread('ladies.png', cv2.IMREAD_GRAYSCALE)
image_target = cv2.imread('boys.jpg', cv2.IMREAD_GRAYSCALE)

equalized_source = cv2.equalizeHist(image_source)

matched_after_equalize = exposure.match_histograms(equalized_source, image_target)

plt.figure(figsize=(15,5))

plt.subplot(1, 3, 1)
plt.imshow(image_source, cmap='gray')
plt.title('Source (Original)')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(equalized_source, cmap='gray')
plt.title('Source (Equalized)')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(matched_after_equalize, cmap='gray')
plt.title('Matched After Equalize')
plt.axis('off')

plt.show()

# %% [markdown]
# In this lab, I used histogram equalization and histogram matching to improve image quality. First, I applied histogram equalization to a grayscale image and the contrast became better and details were clearer. Then, I applied histogram equalization to a color image by processing each color channel separately, which improved contrast but slightly changed the colors. After that, I used histogram matching to make the source image look similar to a target image in brightness and contrast. Finally, I combined both methods by equalizing the image first and then matching it, which gave a clearer result with better brightness and contrast. This lab helped me understand how these methods can be used to enhance images.
